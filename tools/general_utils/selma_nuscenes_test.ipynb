# %%
# %matplotlib inline
from nuscenes.nuscenes import NuScenes

nusc = NuScenes(version='v1.0-mini', dataroot='/hdd/SCANLAB_public/catoad_datasets/data/selma_into_nuscenes', verbose=True)
# Out:
# ======
# Loading NuScenes tables for version v1.0-mini...
# 23 category,
# 8 attribute,
# 4 visibility,
# 182116 instance,
# 3 sensor,
# 3 calibrated_sensor,
# 1634 ego_pose,
# 1 log,
# 1 scene,
# 1634 sample,
# 4902 sample_data,
# 51649 sample_annotation,
# 4 map,
# Done loading in 0.525 seconds.
# ======
# Reverse indexing ...
# Done reverse indexing in 0.1 seconds.
# ======

# %%
my_scene = nusc.scene[0]
my_scene
# Out:
# {'token': 'Town01_Opt_ClearNoon_SELMA',
#  'log_token': 'Town01_SELMA',
#  'nbr_samples': 1634,
#  'first_sample_token': 'Town01_Opt_ClearNoon_3102013609079846627_SELMA',
#  'last_sample_token': 'Town01_Opt_ClearNoon_3272967105842120616_SELMA',
#  'name': 'Town01_Opt_ClearNoon',
#  'description': 'ClearNoon'}

# %%
first_sample_token = my_scene['first_sample_token']

# The rendering command below is commented out because it tends to crash in notebooks
# nusc.render_sample(first_sample_token)

# %%
my_sample = nusc.get('sample', first_sample_token)
my_sample
# Out:
# {'token': 'Town01_Opt_ClearNoon_3102013609079846627_SELMA',
#  'timestamp': 3102013609079846627,
#  'next': 'Town01_Opt_ClearNoon_10187247851921022492_SELMA',
#  'prev': '',
#  'scene_token': 'Town01_Opt_ClearNoon_SELMA',
#  'data': {'LIDAR_TOP': 'Town01_Opt_ClearNoon_3102013609079846627_LIDAR_TOP_SELMA',
#   'CAM_FRONT': 'Town01_Opt_ClearNoon_3102013609079846627_CAM_FRONT_SELMA',
#   'CAM_DESK': 'Town01_Opt_ClearNoon_3102013609079846627_CAM_DESK_SELMA'},
#  'anns': ['Town01_Opt_ClearNoon_3102013609079846627_instance_44911_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44893_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44888_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44939_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44929_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44954_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44945_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44946_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44931_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44907_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44936_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44937_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44941_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44892_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44863_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44957_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44958_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44964_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44965_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44966_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44967_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44969_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44970_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44971_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44972_SELMA',
#   'Town01_Opt_ClearNoon_3102013609079846627_instance_44973_SELMA']}

# %%
nusc.list_sample(my_sample['token'])
# Out:
# Sample: Town01_Opt_ClearNoon_3102013609079846627_SELMA
#
# sample_data_token: Town01_Opt_ClearNoon_3102013609079846627_LIDAR_TOP_SELMA, mod: lidar, channel: LIDAR_TOP
# sample_data_token: Town01_Opt_ClearNoon_3102013609079846627_CAM_FRONT_SELMA, mod: camera, channel: CAM_FRONT
# sample_data_token: Town01_Opt_ClearNoon_3102013609079846627_CAM_DESK_SELMA, mod: camera, channel: CAM_DESK
#
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44911_SELMA, category: human.pedestrian.adult
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44893_SELMA, category: human.pedestrian.adult
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44888_SELMA, category: human.pedestrian.adult
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44939_SELMA, category: human.pedestrian.adult
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44929_SELMA, category: human.pedestrian.adult
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44954_SELMA, category: human.pedestrian.adult
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44945_SELMA, category: human.pedestrian.adult
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44946_SELMA, category: human.pedestrian.adult
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44931_SELMA, category: human.pedestrian.adult
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44907_SELMA, category: human.pedestrian.adult
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44936_SELMA, category: human.pedestrian.adult
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44937_SELMA, category: human.pedestrian.adult
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44941_SELMA, category: human.pedestrian.adult
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44892_SELMA, category: human.pedestrian.adult
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44863_SELMA, category: human.pedestrian.adult
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44957_SELMA, category: vehicle.car
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44958_SELMA, category: vehicle.car
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44964_SELMA, category: vehicle.car
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44965_SELMA, category: vehicle.car
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44966_SELMA, category: vehicle.car
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44967_SELMA, category: vehicle.car
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44969_SELMA, category: vehicle.car
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44970_SELMA, category: vehicle.bicycle
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44971_SELMA, category: vehicle.car
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44972_SELMA, category: vehicle.car
# sample_annotation_token: Town01_Opt_ClearNoon_3102013609079846627_instance_44973_SELMA, category: vehicle.car

# %%
my_sample =nusc.sample[5]

# %%
my_sample['data']
# Out:
# {'LIDAR_TOP': 'Town01_Opt_ClearNoon_11536605642888581651_LIDAR_TOP_SELMA',
#  'CAM_FRONT': 'Town01_Opt_ClearNoon_11536605642888581651_CAM_FRONT_SELMA',
#  'CAM_DESK': 'Town01_Opt_ClearNoon_11536605642888581651_CAM_DESK_SELMA'}

# %%
sensor = 'CAM_DESK'
cam_front_data = nusc.get('sample_data', my_sample['data'][sensor])
cam_front_data
# Out:
# {'token': 'Town01_Opt_ClearNoon_11536605642888581651_CAM_DESK_SELMA',
#  'sample_token': 'Town01_Opt_ClearNoon_11536605642888581651_SELMA',
#  'ego_pose_token': 'Town01_Opt_ClearNoon_11536605642888581651_ego_pose_SELMA',
#  'calibrated_sensor_token': 'CAM_DESK_SELMA',
#  'timestamp': 11536605642888581651,
#  'fileformat': 'jpg',
#  'is_key_frame': True,
#  'height': 1600,
#  'width': 900,
#  'filename': 'samples/CAM_DESK/Town01_Opt_ClearNoon_11536605642888581651.jpg',
#  'prev': '',
#  'next': '',
#  'sensor_modality': 'camera',
#  'channel': 'CAM_DESK'}

# %%
nusc.render_sample_data(cam_front_data['token'])

# %%
my_annotation_token = my_sample['anns'][15]
my_annotation_metadata =  nusc.get('sample_annotation', my_annotation_token)
my_annotation_metadata
# Out:
# {'token': 'Town01_Opt_ClearNoon_11536605642888581651_instance_165638_SELMA',
#  'sample_token': 'Town01_Opt_ClearNoon_11536605642888581651_SELMA',
#  'instance_token': 'Town01_165638',
#  'visibility_token': '4',
#  'attribute_tokens': '',
#  'translation': [392.30950929384676, 188.54028137207933, 0.7334586642682552],
#  'size': [1.97027587890625, 3.805800199508667, 1.4750303030014038],
#  'rotation': [0.7071795605335831,
#   -1.840871485965423e-05,
#   4.099174563132399e-06,
#   0.7070339940963549],
#  'prev': '',
#  'next': '',
#  'num_lidar_pts': 5,
#  'num_radar_pts': 0,
#  'category_name': 'vehicle.car'}

# %%
nusc.render_annotation(my_annotation_token)
